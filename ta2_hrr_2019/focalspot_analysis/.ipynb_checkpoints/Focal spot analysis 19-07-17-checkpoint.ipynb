# %%
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [8.0,8.0]
import matplotlib.pyplot as plt

# %matplotlib inline
from FocalSpot import focal_spot

# %%
import os
def FilesInFolder(DirectoryPath, fileType, starts = ""):
    files = os.listdir(DirectoryPath)
    shots = []
    for i in files:
#        print( i
        if not i.startswith('.') and i.endswith(fileType) and i.startswith(starts):
            shots.append(i)
    return shots

# %%
# Spatial Calibration from grating
def spatial_cal_with_grating():
    """
    Spatial calibration
    
    17.5 cm with 25 slits
    d = 0.007 m
        eq:
            d \sin \theta_{m} = m\lambda
    
    np.deg2rad(np.arcsin( (1 * lambda_l) / d ))        
    """
    d = 0.007
    fl = 1
    lambda_l = 800e-9
    Space_of_diffraction_peaks = lambda_l * fl / d
    return (Space_of_diffraction_peaks)

# %%
folderPath = "/home/chris/Documents/Streeter/Data/FocalSpots_4-9-19/"

laserShots = "PulsedFocus/"
backgroundShots = "bkg/"

# %%
peakSpacing = spatial_cal_with_grating()
print ("Predicted spacing of spots")
print (peakSpacing)

# Positions of the spots from the image, extracted with ImageJ
yPos = np.array([55.97, 170.83, 290])
xPos = np.array([34.12, 147.83, 260.47])
yGap = yPos[1:] - yPos[:-1]
xGap = xPos[1:] - xPos[:-1]

aveSpace = [np.average(yGap), np.average( xGap)]
print ("Measured spacing in pixesl")
print (aveSpace )
print ()
# Out:
# Predicted spacing of spots
# 0.00011428571428571428
# Measured spacing in pixesl
# [117.015, 113.17500000000001]

# %%
pixelSize = peakSpacing /  np.average(aveSpace)
print ("pixels_per_m ", pixelSize)
# Out:
# pixels_per_m  9.929685415153941e-07

# %%
laserFiles = FilesInFolder(folderPath + laserShots, ".tiff")
backgroundFiles = FilesInFolder(folderPath + backgroundShots, ".tiff")

background_sums = []
for i, b in enumerate(backgroundFiles):
    print ("Background File: ", b)
    fs = focal_spot(folderPath + backgroundShots, b, greyScale = True, 
                    calculations = False)    
    background_sums.append(fs.return_energy())
    if i == 0:
        background_aveImage = fs.im
    else:
        background_aveImage += fs.im
background_aveImage = background_aveImage / (i+1)
# Out:
# Background File:  Shot_0233.tiff
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-374b65974828> in <module>()
#       6     print ("Background File: ", b)
#       7     fs = focal_spot(folderPath + backgroundShots, b, greyScale = True,
# ----> 8                     calculations = False)
#       9     background_sums.append(fs.return_energy())
#      10     if i == 0:
#
# TypeError: __init__() got an unexpected keyword argument 'greyScale'

# %%
data_accumulative = []
for l in laserFiles:
    print ("Laser file: ", l)
    fs = focal_spot(folderPath + laserShots, l, greyScale = True, 
                    backgroundImage = background_aveImage)
    if False:
        # Plot some stuff
        # fs.createPlotWithLineOuts(umPerPixel = pixelSize * 1e6)
        fs.plot_scaledImage(umPerPixel = pixelSize * 1e6)   
    fs.calcVals(umPerPixel = pixelSize * 1e6)
    data = fs.valArray(umPerPixel = pixelSize * 1e6)
    # print ("x, y, ave, ratio of energy in spot to out")
    # print (data) 
    data_accumulative.append([data[2], data[3], fs.return_energy()])

# print ("ave, ratio of energy in spot to out, energysum")
# print (data_accumulative)
data_accumulative = np.array(data_accumulative)
ave_size = np.average(data_accumulative[:,0])
ave_ratioEnergyInSpot= np.average(data_accumulative[:,1])
ave_energy = np.average(data_accumulative[:,2])
# Out:
# Laser file:  20190718_FocalSpot_grating_0046.tiff
# Maximum Coordinate (pixel nos):  [328, 236]
# Laser file:  20190718_FocalSpot_grating_0054.tiff
# Maximum Coordinate (pixel nos):  [332, 229]
# Laser file:  20190718_FocalSpot_grating_0038.tiff
# Maximum Coordinate (pixel nos):  [335, 233]
# Laser file:  20190718_FocalSpot_grating_0037.tiff
# Maximum Coordinate (pixel nos):  [336, 232]
# Laser file:  20190718_FocalSpot_grating_0040.tiff
# Maximum Coordinate (pixel nos):  [331, 243]
# Laser file:  20190718_FocalSpot_grating_0041.tiff
# Maximum Coordinate (pixel nos):  [332, 241]
# Laser file:  20190718_FocalSpot_grating_0042.tiff
# Maximum Coordinate (pixel nos):  [331, 233]
# Laser file:  20190718_FocalSpot_grating_0043.tiff
# Maximum Coordinate (pixel nos):  [330, 238]
# Laser file:  20190718_FocalSpot_grating_0039.tiff
# Maximum Coordinate (pixel nos):  [330, 238]
# Laser file:  20190718_FocalSpot_grating_0045.tiff
# Maximum Coordinate (pixel nos):  [329, 243]
# Laser file:  20190718_FocalSpot_grating_0028.tiff
# Maximum Coordinate (pixel nos):  [340, 231]
# Laser file:  20190718_FocalSpot_grating_0025.tiff
# Maximum Coordinate (pixel nos):  [329, 233]
# Laser file:  20190718_FocalSpot_grating_0029.tiff
# Maximum Coordinate (pixel nos):  [332, 235]
# Laser file:  20190718_FocalSpot_grating_0030.tiff
# Maximum Coordinate (pixel nos):  [334, 240]
# Laser file:  20190718_FocalSpot_grating_0026.tiff
# Maximum Coordinate (pixel nos):  [341, 236]
# Laser file:  20190718_FocalSpot_grating_0031.tiff
# Maximum Coordinate (pixel nos):  [334, 238]
# Laser file:  20190718_FocalSpot_grating_0027.tiff
# Maximum Coordinate (pixel nos):  [337, 238]
# Laser file:  20190718_FocalSpot_grating_0044.tiff
# Maximum Coordinate (pixel nos):  [337, 246]
# Laser file:  20190718_FocalSpot_grating_0034.tiff
# Maximum Coordinate (pixel nos):  [322, 236]
# Laser file:  20190718_FocalSpot_grating_0036.tiff
# Maximum Coordinate (pixel nos):  [329, 240]
# Laser file:  20190718_FocalSpot_grating_0035.tiff
# Maximum Coordinate (pixel nos):  [323, 235]
# Laser file:  20190718_FocalSpot_grating_0015.tiff
# Maximum Coordinate (pixel nos):  [329, 233]
# Laser file:  20190718_FocalSpot_grating_0014.tiff
# Maximum Coordinate (pixel nos):  [328, 228]
# Laser file:  20190718_FocalSpot_grating_0012.tiff
# Maximum Coordinate (pixel nos):  [332, 230]
# Laser file:  20190718_FocalSpot_grating_0017.tiff
# Maximum Coordinate (pixel nos):  [332, 228]
# Laser file:  20190718_FocalSpot_grating_0016.tiff
# Maximum Coordinate (pixel nos):  [323, 228]
# Laser file:  20190718_FocalSpot_grating_0032.tiff
# Maximum Coordinate (pixel nos):  [329, 235]
# Laser file:  20190718_FocalSpot_grating_0033.tiff
# Maximum Coordinate (pixel nos):  [328, 237]
# Laser file:  20190718_FocalSpot_grating_0024.tiff
# Maximum Coordinate (pixel nos):  [336, 239]
# Laser file:  20190718_FocalSpot_grating_0022.tiff
# Maximum Coordinate (pixel nos):  [329, 239]
# Laser file:  20190718_FocalSpot_grating_0018.tiff
# Maximum Coordinate (pixel nos):  [325, 217]
# Laser file:  20190718_FocalSpot_grating_0019.tiff
# Maximum Coordinate (pixel nos):  [319, 231]
# Laser file:  20190718_FocalSpot_grating_0023.tiff
# Maximum Coordinate (pixel nos):  [335, 236]
# Laser file:  20190718_FocalSpot_grating_0020.tiff
# Maximum Coordinate (pixel nos):  [327, 230]
# Laser file:  20190718_FocalSpot_grating_0021.tiff
# Maximum Coordinate (pixel nos):  [330, 234]
# Laser file:  20190718_FocalSpot_grating_0010.tiff
# Maximum Coordinate (pixel nos):  [333, 225]
# Laser file:  20190718_FocalSpot_grating_0013.tiff
# Maximum Coordinate (pixel nos):  [330, 229]
# Laser file:  20190718_FocalSpot_grating_0011.tiff
# Maximum Coordinate (pixel nos):  [333, 225]
# Laser file:  20190718_FocalSpot_grating_0005.tiff
# Maximum Coordinate (pixel nos):  [339, 244]
# Laser file:  20190718_FocalSpot_grating_0003.tiff
# Maximum Coordinate (pixel nos):  [332, 243]
# Laser file:  20190718_FocalSpot_grating_0004.tiff
# Maximum Coordinate (pixel nos):  [337, 247]
# Laser file:  20190718_FocalSpot_grating_0001.tiff
# Maximum Coordinate (pixel nos):  [342, 237]
# Laser file:  20190718_FocalSpot_grating_0002.tiff
# Maximum Coordinate (pixel nos):  [339, 241]
# Laser file:  20190718_FocalSpot_grating_0009.tiff
# Maximum Coordinate (pixel nos):  [337, 230]
# Laser file:  20190718_FocalSpot_grating_0008.tiff
# Maximum Coordinate (pixel nos):  [334, 233]
# Laser file:  20190718_FocalSpot_grating_0006.tiff
# Maximum Coordinate (pixel nos):  [329, 236]
# Laser file:  20190718_FocalSpot_grating_0007.tiff
# Maximum Coordinate (pixel nos):  [331, 236]
# Laser file:  20190718_FocalSpot_grating_0097.tiff
# Maximum Coordinate (pixel nos):  [332, 236]
# Laser file:  20190718_FocalSpot_grating_0098.tiff
# Maximum Coordinate (pixel nos):  [331, 233]
# Laser file:  20190718_FocalSpot_grating_0099.tiff
# Maximum Coordinate (pixel nos):  [315, 246]
# Laser file:  20190718_FocalSpot_grating_0096.tiff
# Maximum Coordinate (pixel nos):  [334, 233]
# Laser file:  20190718_FocalSpot_grating_0088.tiff
# Maximum Coordinate (pixel nos):  [327, 227]
# Laser file:  20190718_FocalSpot_grating_0086.tiff
# Maximum Coordinate (pixel nos):  [334, 235]
# Laser file:  20190718_FocalSpot_grating_0087.tiff
# Maximum Coordinate (pixel nos):  [332, 237]
# Laser file:  20190718_FocalSpot_grating_0085.tiff
# Maximum Coordinate (pixel nos):  [332, 234]
# Laser file:  20190718_FocalSpot_grating_0089.tiff
# Maximum Coordinate (pixel nos):  [329, 229]
# Laser file:  20190718_FocalSpot_grating_0091.tiff
# Maximum Coordinate (pixel nos):  [340, 231]
# Laser file:  20190718_FocalSpot_grating_0094.tiff
# Maximum Coordinate (pixel nos):  [333, 235]
# Laser file:  20190718_FocalSpot_grating_0090.tiff
# Maximum Coordinate (pixel nos):  [343, 238]
# Laser file:  20190718_FocalSpot_grating_0095.tiff
# Maximum Coordinate (pixel nos):  [324, 228]
# Laser file:  20190718_FocalSpot_grating_0092.tiff
# Maximum Coordinate (pixel nos):  [327, 226]
# Laser file:  20190718_FocalSpot_grating_0075.tiff
# Maximum Coordinate (pixel nos):  [345, 248]
# Laser file:  20190718_FocalSpot_grating_0073.tiff
# Maximum Coordinate (pixel nos):  [314, 223]
# Laser file:  20190718_FocalSpot_grating_0076.tiff
# Maximum Coordinate (pixel nos):  [320, 235]
# Laser file:  20190718_FocalSpot_grating_0077.tiff
# Maximum Coordinate (pixel nos):  [334, 236]
# Laser file:  20190718_FocalSpot_grating_0074.tiff
# Maximum Coordinate (pixel nos):  [293, 223]
# Laser file:  20190718_FocalSpot_grating_0079.tiff
# Maximum Coordinate (pixel nos):  [328, 241]
# Laser file:  20190718_FocalSpot_grating_0093.tiff
# Maximum Coordinate (pixel nos):  [331, 231]
# Laser file:  20190718_FocalSpot_grating_0078.tiff
# Maximum Coordinate (pixel nos):  [336, 241]
# Laser file:  20190718_FocalSpot_grating_0083.tiff
# Maximum Coordinate (pixel nos):  [331, 246]
# Laser file:  20190718_FocalSpot_grating_0084.tiff
# Maximum Coordinate (pixel nos):  [331, 241]
# Laser file:  20190718_FocalSpot_grating_0082.tiff
# Maximum Coordinate (pixel nos):  [332, 236]
# Laser file:  20190718_FocalSpot_grating_0080.tiff
# Maximum Coordinate (pixel nos):  [332, 242]
# Laser file:  20190718_FocalSpot_grating_0081.tiff
# Maximum Coordinate (pixel nos):  [329, 235]
# Laser file:  20190718_FocalSpot_grating_0071.tiff
# Maximum Coordinate (pixel nos):  [340, 236]
# Laser file:  20190718_FocalSpot_grating_0060.tiff
# Maximum Coordinate (pixel nos):  [331, 230]
# Laser file:  20190718_FocalSpot_grating_0059.tiff
# Maximum Coordinate (pixel nos):  [331, 235]
# Laser file:  20190718_FocalSpot_grating_0062.tiff
# Maximum Coordinate (pixel nos):  [347, 240]
# Laser file:  20190718_FocalSpot_grating_0064.tiff
# Maximum Coordinate (pixel nos):  [348, 243]
# Laser file:  20190718_FocalSpot_grating_0061.tiff
# Maximum Coordinate (pixel nos):  [333, 235]
# Laser file:  20190718_FocalSpot_grating_0063.tiff
# Maximum Coordinate (pixel nos):  [342, 237]
# Laser file:  20190718_FocalSpot_grating_0072.tiff
# Maximum Coordinate (pixel nos):  [339, 235]
# Laser file:  20190718_FocalSpot_grating_0070.tiff
# Maximum Coordinate (pixel nos):  [343, 238]
# Laser file:  20190718_FocalSpot_grating_0065.tiff
# Maximum Coordinate (pixel nos):  [341, 247]
# Laser file:  20190718_FocalSpot_grating_0068.tiff
# Maximum Coordinate (pixel nos):  [333, 248]
# Laser file:  20190718_FocalSpot_grating_0069.tiff
# Maximum Coordinate (pixel nos):  [340, 244]
# Laser file:  20190718_FocalSpot_grating_0067.tiff
# Maximum Coordinate (pixel nos):  [336, 244]
# Laser file:  20190718_FocalSpot_grating_0050.tiff
# Maximum Coordinate (pixel nos):  [318, 237]
# Laser file:  20190718_FocalSpot_grating_0047.tiff
# Maximum Coordinate (pixel nos):  [324, 248]
# Laser file:  20190718_FocalSpot_grating_0051.tiff
# Maximum Coordinate (pixel nos):  [321, 233]
# Laser file:  20190718_FocalSpot_grating_0052.tiff
# Maximum Coordinate (pixel nos):  [325, 223]
# Laser file:  20190718_FocalSpot_grating_0053.tiff
# Maximum Coordinate (pixel nos):  [336, 226]
# Laser file:  20190718_FocalSpot_grating_0049.tiff
# Maximum Coordinate (pixel nos):  [330, 243]
# Laser file:  20190718_FocalSpot_grating_0048.tiff
# Maximum Coordinate (pixel nos):  [328, 250]
# Laser file:  20190718_FocalSpot_grating_0066.tiff
# Maximum Coordinate (pixel nos):  [341, 250]
# Laser file:  20190718_FocalSpot_grating_0058.tiff
# Maximum Coordinate (pixel nos):  [327, 239]
# Laser file:  20190718_FocalSpot_grating_0057.tiff
# Maximum Coordinate (pixel nos):  [329, 236]
# Laser file:  20190718_FocalSpot_grating_0056.tiff
# Maximum Coordinate (pixel nos):  [330, 228]
# Laser file:  20190718_FocalSpot_grating_0055.tiff
# Maximum Coordinate (pixel nos):  [337, 230]

# %%
aveBackgroundCount = np.average(background_sums)
print ("\n\nAverage FWHM (um)\t", ave_size, 
       "\nAve Energy in spot ratio\t", ave_ratioEnergyInSpot, 
       "\nAverage count (energy) in image\t", ave_energy - aveBackgroundCount)
# Out:
# Average FWHM (um)	 20.10510546936977
# Ave Energy in spot ratio	 0.2358573700253768
# Average count (energy) in image	 1121500.7171717172

# %%
# Working out the peak intensity

intensity_list = []
for l in laserFiles[:]:
    print ("Laser file: ", l)
    fs = focal_spot(folderPath + laserShots, l, greyScale = True, 
                    backgroundImage = background_aveImage, calculations = False)

    I = fs.im
    dx = pixelSize
    peakPowerTW_per_j = 4.92
    I = I / np.sum(I) / (dx * dx) * peakPowerTW_per_j
    if False:
        plt.imshow(I)
        plt.colorbar()
        plt.show()
    print ("Peak Intensity", I.max() * 1e12)
    intensity_list.append(I.max() * 1e12)
    
print ("\n\nAverage peak intensity", np.average(intensity_list) )
# Out:
# Laser file:  20190718_FocalSpot_grating_0046.tiff
# Peak Intensity 9.292253750014204e+21
# Laser file:  20190718_FocalSpot_grating_0054.tiff
# Peak Intensity 9.090501093845201e+21
# Laser file:  20190718_FocalSpot_grating_0038.tiff
# Peak Intensity 4.649122548350415e+21
# Laser file:  20190718_FocalSpot_grating_0037.tiff
# Peak Intensity 6.621130825423889e+21
# Laser file:  20190718_FocalSpot_grating_0040.tiff
# Peak Intensity 8.029966435730356e+21
# Laser file:  20190718_FocalSpot_grating_0041.tiff
# Peak Intensity 8.546189561018216e+21
# Laser file:  20190718_FocalSpot_grating_0042.tiff
# Peak Intensity 6.397722118268703e+21
# Laser file:  20190718_FocalSpot_grating_0043.tiff
# Peak Intensity 8.776210019970892e+21
# Laser file:  20190718_FocalSpot_grating_0039.tiff
# Peak Intensity 7.836086407784269e+21
# Laser file:  20190718_FocalSpot_grating_0045.tiff
# Peak Intensity 8.87232271541103e+21
# Laser file:  20190718_FocalSpot_grating_0028.tiff
# Peak Intensity 9.382051073210514e+21
# Laser file:  20190718_FocalSpot_grating_0025.tiff
# Peak Intensity 9.60402221740787e+21
# Laser file:  20190718_FocalSpot_grating_0029.tiff
# Peak Intensity 8.379780027768553e+21
# Laser file:  20190718_FocalSpot_grating_0030.tiff
# Peak Intensity 8.725505281024874e+21
# Laser file:  20190718_FocalSpot_grating_0026.tiff
# Peak Intensity 9.402500641756195e+21
# Laser file:  20190718_FocalSpot_grating_0031.tiff
# Peak Intensity 9.46178481010513e+21
# Laser file:  20190718_FocalSpot_grating_0027.tiff
# Peak Intensity 9.267906054177093e+21
# Laser file:  20190718_FocalSpot_grating_0044.tiff
# Peak Intensity 8.984999173122306e+21
# Laser file:  20190718_FocalSpot_grating_0034.tiff
# Peak Intensity 9.031397681536029e+21
# Laser file:  20190718_FocalSpot_grating_0036.tiff
# Peak Intensity 8.192705389505044e+21
# Laser file:  20190718_FocalSpot_grating_0035.tiff
# Peak Intensity 8.839981424119143e+21
# Laser file:  20190718_FocalSpot_grating_0015.tiff
# Peak Intensity 9.227600684616757e+21
# Laser file:  20190718_FocalSpot_grating_0014.tiff
# Peak Intensity 9.62054753522684e+21
# Laser file:  20190718_FocalSpot_grating_0012.tiff
# Peak Intensity 9.334266438851377e+21
# Laser file:  20190718_FocalSpot_grating_0017.tiff
# Peak Intensity 8.471695643007344e+21
# Laser file:  20190718_FocalSpot_grating_0016.tiff
# Peak Intensity 8.924488974338053e+21
# Laser file:  20190718_FocalSpot_grating_0032.tiff
# Peak Intensity 9.520550817409675e+21
# Laser file:  20190718_FocalSpot_grating_0033.tiff
# Peak Intensity 9.565153729831003e+21
# Laser file:  20190718_FocalSpot_grating_0024.tiff
# Peak Intensity 8.909881192681524e+21
# Laser file:  20190718_FocalSpot_grating_0022.tiff
# Peak Intensity 8.902165982529492e+21
# Laser file:  20190718_FocalSpot_grating_0018.tiff
# Peak Intensity 8.730716840399107e+21
# Laser file:  20190718_FocalSpot_grating_0019.tiff
# Peak Intensity 9.53638136476004e+21
# Laser file:  20190718_FocalSpot_grating_0023.tiff
# Peak Intensity 8.734284406108734e+21
# Laser file:  20190718_FocalSpot_grating_0020.tiff
# Peak Intensity 8.821108022123441e+21
# Laser file:  20190718_FocalSpot_grating_0021.tiff
# Peak Intensity 8.845152456967692e+21
# Laser file:  20190718_FocalSpot_grating_0010.tiff
# Peak Intensity 8.842792046174827e+21
# Laser file:  20190718_FocalSpot_grating_0013.tiff
# Peak Intensity 9.231669753375837e+21
# Laser file:  20190718_FocalSpot_grating_0011.tiff
# Peak Intensity 8.835530663775814e+21
# Laser file:  20190718_FocalSpot_grating_0005.tiff
# Peak Intensity 8.210583588993639e+21
# Laser file:  20190718_FocalSpot_grating_0003.tiff
# Peak Intensity 9.069575055292593e+21
# Laser file:  20190718_FocalSpot_grating_0004.tiff
# Peak Intensity 6.278833886644356e+21
# Laser file:  20190718_FocalSpot_grating_0001.tiff
# Peak Intensity 8.433414363580519e+21
# Laser file:  20190718_FocalSpot_grating_0002.tiff
# Peak Intensity 5.975941475500573e+21
# Laser file:  20190718_FocalSpot_grating_0009.tiff
# Peak Intensity 7.665264045577789e+21
# Laser file:  20190718_FocalSpot_grating_0008.tiff
# Peak Intensity 9.074355970901888e+21
# Laser file:  20190718_FocalSpot_grating_0006.tiff
# Peak Intensity 9.07837738752776e+21
# Laser file:  20190718_FocalSpot_grating_0007.tiff
# Peak Intensity 9.04439110261478e+21
# Laser file:  20190718_FocalSpot_grating_0097.tiff
# Peak Intensity 8.840626960708206e+21
# Laser file:  20190718_FocalSpot_grating_0098.tiff
# Peak Intensity 8.671103349555996e+21
# Laser file:  20190718_FocalSpot_grating_0099.tiff
# Peak Intensity 4.813112174077736e+21
# Laser file:  20190718_FocalSpot_grating_0096.tiff
# Peak Intensity 8.595306245553975e+21
# Laser file:  20190718_FocalSpot_grating_0088.tiff
# Peak Intensity 6.824769550795633e+21
# Laser file:  20190718_FocalSpot_grating_0086.tiff
# Peak Intensity 9.631201299958843e+21
# Laser file:  20190718_FocalSpot_grating_0087.tiff
# Peak Intensity 8.695427852894451e+21
# Laser file:  20190718_FocalSpot_grating_0085.tiff
# Peak Intensity 9.364999599991812e+21
# Laser file:  20190718_FocalSpot_grating_0089.tiff
# Peak Intensity 7.3644706945255e+21
# Laser file:  20190718_FocalSpot_grating_0091.tiff
# Peak Intensity 8.95891390618232e+21
# Laser file:  20190718_FocalSpot_grating_0094.tiff
# Peak Intensity 8.705621524842646e+21
# Laser file:  20190718_FocalSpot_grating_0090.tiff
# Peak Intensity 8.590782392052689e+21
# Laser file:  20190718_FocalSpot_grating_0095.tiff
# Peak Intensity 9.265825822115836e+21
# Laser file:  20190718_FocalSpot_grating_0092.tiff
# Peak Intensity 9.313907496919899e+21
# Laser file:  20190718_FocalSpot_grating_0075.tiff
# Peak Intensity 9.234599675976716e+21
# Laser file:  20190718_FocalSpot_grating_0073.tiff
# Peak Intensity 9.612221794515692e+21
# Laser file:  20190718_FocalSpot_grating_0076.tiff
# Peak Intensity 9.558668597744814e+21
# Laser file:  20190718_FocalSpot_grating_0077.tiff
# Peak Intensity 8.35336427557904e+21
# Laser file:  20190718_FocalSpot_grating_0074.tiff
# Peak Intensity 8.159314207645788e+21
# Laser file:  20190718_FocalSpot_grating_0079.tiff
# Peak Intensity 7.614156473742094e+21
# Laser file:  20190718_FocalSpot_grating_0093.tiff
# Peak Intensity 9.045963859095426e+21
# Laser file:  20190718_FocalSpot_grating_0078.tiff
# Peak Intensity 6.30091826807e+21
# Laser file:  20190718_FocalSpot_grating_0083.tiff
# Peak Intensity 7.717717032716581e+21
# Laser file:  20190718_FocalSpot_grating_0084.tiff
# Peak Intensity 8.694813265941063e+21
# Laser file:  20190718_FocalSpot_grating_0082.tiff
# Peak Intensity 7.629909154384267e+21
# Laser file:  20190718_FocalSpot_grating_0080.tiff
# Peak Intensity 7.553283796377959e+21
# Laser file:  20190718_FocalSpot_grating_0081.tiff
# Peak Intensity 9.162298308566462e+21
# Laser file:  20190718_FocalSpot_grating_0071.tiff
# Peak Intensity 8.702608633578524e+21
# Laser file:  20190718_FocalSpot_grating_0060.tiff
# Peak Intensity 8.495794294310694e+21
# Laser file:  20190718_FocalSpot_grating_0059.tiff
# Peak Intensity 8.677787036997225e+21
# Laser file:  20190718_FocalSpot_grating_0062.tiff
# Peak Intensity 7.115855952805458e+21
# Laser file:  20190718_FocalSpot_grating_0064.tiff
# Peak Intensity 7.530347642959658e+21
# Laser file:  20190718_FocalSpot_grating_0061.tiff
# Peak Intensity 7.615486348472142e+21
# Laser file:  20190718_FocalSpot_grating_0063.tiff
# Peak Intensity 7.717289679341187e+21
# Laser file:  20190718_FocalSpot_grating_0072.tiff
# Peak Intensity 8.487301329646097e+21
# Laser file:  20190718_FocalSpot_grating_0070.tiff
# Peak Intensity 8.53671114504009e+21
# Laser file:  20190718_FocalSpot_grating_0065.tiff
# Peak Intensity 7.60980080681831e+21
# Laser file:  20190718_FocalSpot_grating_0068.tiff
# Peak Intensity 6.672257975751199e+21
# Laser file:  20190718_FocalSpot_grating_0069.tiff
# Peak Intensity 7.065286799010312e+21
# Laser file:  20190718_FocalSpot_grating_0067.tiff
# Peak Intensity 6.671697956249259e+21
# Laser file:  20190718_FocalSpot_grating_0050.tiff
# Peak Intensity 7.599632124752894e+21
# Laser file:  20190718_FocalSpot_grating_0047.tiff
# Peak Intensity 7.110088090628677e+21
# Laser file:  20190718_FocalSpot_grating_0051.tiff
# Peak Intensity 4.5150691197559793e+21
# Laser file:  20190718_FocalSpot_grating_0052.tiff
# Peak Intensity 6.598191275785256e+21
# Laser file:  20190718_FocalSpot_grating_0053.tiff
# Peak Intensity 8.65430919648077e+21
# Laser file:  20190718_FocalSpot_grating_0049.tiff
# Peak Intensity 8.941487001237427e+21
# Laser file:  20190718_FocalSpot_grating_0048.tiff
# Peak Intensity 8.685875674006237e+21
# Laser file:  20190718_FocalSpot_grating_0066.tiff
# Peak Intensity 5.464587199421711e+21
# Laser file:  20190718_FocalSpot_grating_0058.tiff
# Peak Intensity 8.031070495108684e+21
# Laser file:  20190718_FocalSpot_grating_0057.tiff
# Peak Intensity 9.474395721444757e+21
# Laser file:  20190718_FocalSpot_grating_0056.tiff
# Peak Intensity 8.901695040054304e+21
# Laser file:  20190718_FocalSpot_grating_0055.tiff
# Peak Intensity 8.566599069757283e+21
#
#
# Average peak intensity 8.323064503720272e+21
